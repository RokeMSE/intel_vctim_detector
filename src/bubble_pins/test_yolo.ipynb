# %%
""" !pip install ultralytics """
from ultralytics import YOLO

# Load a model
model = YOLO('yolo11m.pt') 

# Train the model
# data.yml should point to dataset of grid images
results = model.train(
    data='data.yml', 
    epochs=100, 
    imgsz=640, 
    batch=32,
    name='pin_detector'
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.250 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.235  Python-3.13.7 torch-2.9.1+cu128 CUDA:0 (NVIDIA GeForce RTX 5070 Ti Laptop GPU, 12227MiB)
# engine\trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yml, degrees=0.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo11m.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=pin_detector, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=C:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\bubble_pins\runs\detect\pin_detector, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  23        [16, 19, 22]  1   1411795  ultralytics.nn.modules.head.Detect           [1, [256, 512, 512]]
# YOLO11m summary: 231 layers, 20,053,779 parameters, 20,053,763 gradients, 68.2 GFLOPs
#
# Transferred 643/649 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed
# train: Fast image access  (ping: 0.00.0 ms, read: 133.942.3 MB/s, size: 65.5 KB)
# train: Scanning C:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\bubble_pins\data\yolo\train\labels.cache... 24 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 24/24 51.4Kit/s 0.0s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access  (ping: 0.00.0 ms, read: 124.225.0 MB/s, size: 66.9 KB)
# val: Scanning C:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\bubble_pins\data\yolo\valid\labels.cache... 3 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 3/3 3.2Kit/s 0.0s0s
# Plotting labels to C:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\bubble_pins\runs\detect\pin_detector\labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.002, momentum=0.9) with parameter groups 106 weight(decay=0.0), 113 weight(decay=0.0005), 112 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to C:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\bubble_pins\runs\detect\pin_detector
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       1/100      18.5G      4.962      4.096      1.773  6.338e+04        640: 100% ━━━━━━━━━━━━ 1/1 193.0s/it 3:13
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 1.5s/it 1.5s
#                    all          3       5413          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       2/100      18.2G      4.863      4.146      1.783  5.297e+04        640: 100% ━━━━━━━━━━━━ 1/1 168.8s/it 2:49
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.5it/s 0.3s
#                    all          3       5413          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       3/100      17.8G      4.999      4.117      1.863  5.242e+04        640: 100% ━━━━━━━━━━━━ 1/1 136.8s/it 2:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.2it/s 0.2s
#                    all          3       5413          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       4/100      18.6G      4.853      4.163      1.778  5.251e+04        640: 100% ━━━━━━━━━━━━ 1/1 182.7s/it 3:03
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          3       5413          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       5/100      18.5G      4.926       4.01      1.925    5.1e+04        640: 100% ━━━━━━━━━━━━ 1/1 174.1s/it 2:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.9it/s 0.2s
#                    all          3       5413          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       6/100      18.7G      5.086      4.114      1.878  5.864e+04        640: 100% ━━━━━━━━━━━━ 1/1 189.3s/it 3:09
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.8it/s 0.2s
#                    all          3       5413          0          0          0          0
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       7/100        22G      5.127      4.022      1.882   4.78e+04        640: 100% ━━━━━━━━━━━━ 1/1 110.2s/it 1:50
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 3.9it/s 0.3s
#                    all          3       5413     0.0922     0.0153     0.0511     0.0182
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       8/100      18.3G      3.406      2.965      1.353  4.183e+04        640: 100% ━━━━━━━━━━━━ 1/1 155.9s/it 2:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.2it/s 0.2s
#                    all          3       5413      0.257     0.0285     0.0901     0.0209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#       9/100        19G      2.631      1.849      1.031  6.181e+04        640: 100% ━━━━━━━━━━━━ 1/1 195.1s/it 3:15
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.1it/s 0.2s
#                    all          3       5413      0.418     0.0464      0.153     0.0525
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#      10/100      20.8G      2.582      1.178      1.029  5.311e+04        640: 100% ━━━━━━━━━━━━ 1/1 271.1s/it 4:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.2it/s 0.2s
#                    all          3       5413      0.437     0.0484      0.159     0.0729
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#      11/100      18.1G      2.772      1.234      1.053  5.474e+04        640: 100% ━━━━━━━━━━━━ 1/1 145.5s/it 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.2it/s 0.2s
#                    all          3       5413      0.859      0.143      0.491      0.231
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#      12/100      18.8G      2.595     0.9148     0.9957  6.221e+04        640: 100% ━━━━━━━━━━━━ 1/1 185.9s/it 3:06
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.3it/s 0.2s
#                    all          3       5413      0.562     0.0935      0.308      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#      13/100      18.4G      2.168     0.7951      1.033  4.753e+04        640: 100% ━━━━━━━━━━━━ 1/1 166.1s/it 2:46
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.6it/s 0.2s
#                    all          3       5413      0.582     0.0968      0.322      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#      14/100      18.2G      2.214     0.7234      1.055  5.319e+04        640: 100% ━━━━━━━━━━━━ 1/1 154.6s/it 2:35
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          3       5413      0.786      0.131      0.447      0.193
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#      15/100      19.7G      2.492     0.7135      1.032  6.211e+04        640: 100% ━━━━━━━━━━━━ 1/1 233.6s/it 3:54
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.0it/s 0.3s
#                    all          3       5413       0.86      0.143      0.495      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#      16/100      19.2G      2.093     0.6283      1.041  5.479e+04        640: 100% ━━━━━━━━━━━━ 1/1 215.6s/it 3:36
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          3       5413      0.868      0.144        0.5      0.206
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#      17/100      19.1G      2.404     0.7671      0.993  6.574e+04        640: 100% ━━━━━━━━━━━━ 1/1 216.9s/it 3:37
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.5it/s 0.2s
#                    all          3       5413      0.907      0.151      0.524      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU
#      18/100      20.4G      2.075     0.6097      1.004  5.611e+04        640: 100% ━━━━━━━━━━━━ 1/1 256.7s/it 4:17
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 1/1 4.7it/s 0.2s
#                    all          3       5413        0.9       0.15      0.519      0.234
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
# WARNING CUDA OutOfMemoryError in TaskAlignedAssigner, using CPU

# %%
import cv2
from ultralytics import YOLO
import os
import torch

if torch.cuda.is_available():
    device = 'cuda'
    print("CUDA available")
else:
    device = 'cpu'

model = YOLO('./runs/detect/vctim_detector/weights/best.pt')
img_path = './data/test/'
results = model(img_path)

model.export(format='openvino')
for result in results:
    boxes = result.boxes
    for box in boxes:
        x1, y1, x2, y2 = box.xyxy[0]
        conf = box.conf[0]
        cls = int(box.cls[0])
        label = model.names[cls] 
        
        print(f"Detected {label} with confidence {conf:.2f} for test image {result.path.split('/')[-1]}")

    # Visualize
    res_plotted = result.plot()
    cv2.imshow("Result", res_plotted)
    cv2.waitKey(0)
# Out:
# CUDA available
#
# image 1/3 c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\08bb596d-WIN_20251210_09_38_30_Pro.jpg: 384x640 1 missing_vctim, 2 normals, 32.5ms
# image 2/3 c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\7ede1f9f-WIN_20251210_09_49_49_Pro.jpg: 384x640 3 normals, 31.6ms
# image 3/3 c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\8cb58d42-WIN_20251210_09_42_56_Pro.jpg: 384x640 1 normal, 22.2ms
# Speed: 1.9ms preprocess, 28.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Ultralytics 8.3.235  Python-3.13.7 torch-2.9.1+cu128 CPU (AMD Ryzen 9 8940HX with Radeon Graphics)
#
# PyTorch: starting from 'runs\detect\vctim_detector2\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 6, 8400) (38.6 MB)
#
# OpenVINO: starting export with openvino 2025.4.0-20398-7a975177ff4-releases/2025/4...
# OpenVINO: export success  2.1s, saved as 'runs\detect\vctim_detector2\weights\best_openvino_model\' (76.9 MB)
#
# Export complete (2.4s)
# Results saved to C:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\runs\detect\vctim_detector2\weights
# Predict:         yolo predict task=detect model=runs\detect\vctim_detector2\weights\best_openvino_model imgsz=640
# Validate:        yolo val task=detect model=runs\detect\vctim_detector2\weights\best_openvino_model imgsz=640 data=data.yml
# Visualize:       https://netron.app
# Detected missing_vctim with confidence 0.85 for test image c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\08bb596d-WIN_20251210_09_38_30_Pro.jpg
# Detected normal with confidence 0.38 for test image c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\08bb596d-WIN_20251210_09_38_30_Pro.jpg
# Detected normal with confidence 0.28 for test image c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\08bb596d-WIN_20251210_09_38_30_Pro.jpg
# Detected normal with confidence 0.41 for test image c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\7ede1f9f-WIN_20251210_09_49_49_Pro.jpg
# Detected normal with confidence 0.40 for test image c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\7ede1f9f-WIN_20251210_09_49_49_Pro.jpg
# Detected normal with confidence 0.36 for test image c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\7ede1f9f-WIN_20251210_09_49_49_Pro.jpg
# Detected normal with confidence 0.95 for test image c:\Users\rokeM\Downloads\Intel\Prj1\intel_vctim_detector\src\data\test\8cb58d42-WIN_20251210_09_42_56_Pro.jpg
